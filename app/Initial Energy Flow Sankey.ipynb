# %% [markdown]
# # DISSERTAÇÃO DE MESTRADO
#
# ## Gráficos dos cenários

# %% [markdown]
# @author: Guilherme Nogueira

# %% [markdown]
# ## Importações

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
# Personalizado
from functions.sankey import plot_sankey_base_vs_cenario

# %% [markdown]
# ## Cenário Base

# %%
valores_base = {
    "Derivados de Petróleo": 56168.35,
    "Biodiesel": 3474.00,
    "Etanol": 15717.54,
    "Eletricidade (GC)": 163.14,
    "Eletricidade (GD)": 6.13,
    "Gás Natural": 1946.32
}

# %% [markdown]
# ## Base para Cenário 1

# %%
valores_c1 = {
    "Derivados de Petróleo": 0.00,
    "Biodiesel": 39327.71,
    "Etanol": 37175.30,
    "Eletricidade (GC)": 932.65,
    "Eletricidade (GD)": 35.90,
    "Gás Natural": 0.00
}

plot_sankey_base_vs_cenario(
    cenario_nome="C1",
    valores_base=valores_base,
    valores_cenario=valores_c1,
    output_path="../data/graphs/base-cen1.pdf",
    tamanho_fonte=15
)

# %% [markdown]
# ## Base para Cenário 2

# %%
valores_c2 = {
    "Derivados de Petróleo": 39138.11,
    "Biodiesel": 3474.00,
    "Etanol": 15717.54,
    "Eletricidade (GC)": 18188.63,
    "Eletricidade (GD)": 957.20,
    "Gás Natural": 0.00
}

plot_sankey_base_vs_cenario(
    cenario_nome="C2",
    valores_base=valores_base,
    valores_cenario=valores_c2,
    output_path="../data/graphs/base-cen2.pdf",
    tamanho_fonte=15
)

# %% [markdown]
# ## Base para Cenário 3

# %%
valores_c3 = {
    "Derivados de Petróleo": 22467.34,
    "Biodiesel": 17219.84,
    "Etanol": 37619.03,
    "Eletricidade (GC)": 163.14,
    "Eletricidade (GD)": 6.13,
    "Gás Natural": 0.00
}

plot_sankey_base_vs_cenario(
    cenario_nome="C3",
    valores_base=valores_base,
    valores_cenario=valores_c3,
    output_path="../data/graphs//base-cen3.pdf"
)
